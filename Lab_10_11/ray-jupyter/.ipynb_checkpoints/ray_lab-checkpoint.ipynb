# %% [markdown]
# # Platforma ray
# #### Łukasz Kochańczyk, gr. 1

# %%
import ray
import time
ray.init(dashboard_host='0.0.0.0', ignore_reinit_error=True)
# Out:
# 2024-05-23 17:26:39,718	INFO worker.py:1582 -- Calling ray.init() again after it has already been called.
# RayContext(dashboard_url='172.17.0.2:8265', python_version='3.10.12', ray_version='2.22.0', ray_commit='a8ab7b87a59b833242fe3564c61d7b39265cd838')

# %%
# ray.shutdown()

# %% [markdown]
# Tablica *Dashboard* jest dostępna pod adresem http://localhost:8265

# %% [markdown]
# ## 1. Zadania (Tasks)
# Cytując: *"Ray enables arbitrary functions to be executed asynchronously on separate Python workers. Such functions are called Ray remote functions and their asynchronous invocations are called Ray tasks."*

# %%
@ray.remote
def suma(a, b):
    return a + b

# %%
# To nie zadziała
# suma(1, 2)

# %%
# Sprawdż dashboard
suma.remote(1, 2)
# Out:
# ObjectRef(64fb3f59141f6b51ffffffffffffffffffffffff0100000001000000)

# %%
result_ref = suma.remote(1,2)
# Pobierz wynik
ray.get(result_ref)
# Out:
# 3

# %% [markdown]
# ### 1.1 Składanie wywołań

# %%
result_ref = suma.remote(suma.remote(1, 2), suma.remote(3, 4))
ray.get(result_ref)
# Out:
# 10

# %% [markdown]
# Zadania ```suma.remote(1,2)``` i ```suma.remote(3,4)``` mogą być wykonywane współbieżnie na różnych węzłach obliczeniowych. Zadanie zwracające ostateczny wynik będzie oczekiwało na zakończenie poprzednich.
#
# Ray analizuje zależności między funkcjami i tworzy graf zależności, który jest używany do efektywnego i równoległego wykonania zadań.

# %%
r1 = suma.remote(1, 2)
r2 = suma.remote(3, 4)
result_ref = suma.remote(r1, r2)
ray.get(result_ref)
# Out:
# 10

# %% [markdown]
# ### 1.2 Jeśli funkcja nie zwraca wartości

# %%
@ray.remote
def void_foo(*params):
    for k in params:
        print(k, end=' ')
    print()

void_foo.remote(1, 'ala', 3.5, True)
# Out:
# ObjectRef(cff1dd57d8c73064ffffffffffffffffffffffff0100000001000000)

# %% [markdown]
# **TODO 1.2.1** Znajdź wydruk Dashboard:Jobs > void_foo > stdout

# %% [markdown]
# ![image.png](attachment:0a63d624-808e-4d60-9faa-b33bf58c05a5.png)

# %% [markdown]
# ### 1.3 Ciąg Fibonacciego -  rekurencja
# Napisz funkcję obliczającą rekurencyjnie n-tą wartość ciągu Fibbonaciego.
# Sprawdź na tablicy Dashboard ile razy była wywołana funckja dla róznych wartości parametrów (ale raczej n <= 10)

# %%
@ray.remote
def fibo(n):
    print(n)
    if n <= 1:
        return n
    else:
        return ray.get(fibo.remote(n-1)) + ray.get(fibo.remote(n-2))

obj_ref = fibo.remote(10)
ray.get(obj_ref)
# Out:
# 55

# %% [markdown]
# ### 1.4 Ciąg Fibonacciego -  iteracyjnie

# %%
@ray.remote
def next_fibo_number(a, b):
    return a + b

obj_ref = next_fibo_number.remote(1, 2)
ray.get(obj_ref)
# Out:
# 3

# %% [markdown]
# **TODO 1.4.1** Wykorzystaj funcję ```next_fibo_number``` do wzynaczenia elementu ciągu Fibboncciego o mnumerze 102

# %%
r1 = fibo.remote(5)
r2 = fibo.remote(6)
obj_ref3 = next_fibo_number.remote(r1, r2)
ray.get(obj_ref3)
# Out:
# 13

# %% [markdown]
# Dlaczego w tej wersji działa znacznie szybciej? Jak (zapewne) wyglądają drzewa zależnoci w tych dwóch przypadkach?

# %% [markdown]
# ### 1.5 Obliczanie pi

# %% [markdown]
# **TODO 1.5.1** Napisz funkcję zgodnie ze specyfikacją

# %%
import random
num_slices = 100
slice_size = 1_000_000

@ray.remote
def compute_pi_on_slice(slice_size):
    in_circle = 0
    for _ in range(slice_size):
        x, y = random.random(), random.random()
        if x**2 + y**2 <= 1:
            in_circle += 1

    return 4 * in_circle / slice_size
   

object_ref = compute_pi_on_slice.remote(slice_size=slice_size)
ray.get(object_ref)
# Out:
# 3.143136

# %%
# Dashboard
tab_ref = [compute_pi_on_slice.remote(slice_size=slice_size) for i in range(num_slices)]

# %%
# Pobiera wszystkie elementy
ray.get(tab_ref)
# Out:
# [3.141136,
#  3.139724,
#  3.144092,
#  3.14428,
#  3.140964,
#  3.1404,
#  3.139912,
#  3.143056,
#  3.142616,
#  3.142816,
#  3.139316,
#  3.145108,
#  3.144084,
#  3.141692,
#  3.141276,
#  3.141904,
#  3.143212,
#  3.141812,
#  3.14308,
#  3.139856,
#  3.141928,
#  3.142076,
#  3.142496,
#  3.144012,
#  3.143024,
#  3.14032,
#  3.141536,
#  3.143344,
#  3.138136,
#  3.142456,
#  3.141236,
#  3.141524,
#  3.139404,
#  3.14184,
#  3.13964,
#  3.144492,
#  3.142752,
#  3.138816,
#  3.139652,
#  3.140036,
#  3.143732,
#  3.141356,
#  3.138244,
#  3.141948,
#  3.141564,
#  3.14102,
#  3.143304,
#  3.142008,
#  3.138948,
#  3.138556,
#  3.14098,
#  3.139312,
#  3.14522,
#  3.140084,
#  3.13948,
#  3.141412,
#  3.139164,
#  3.138516,
#  3.142404,
#  3.144472,
#  3.141928,
#  3.142944,
#  3.143036,
#  3.140628,
#  3.14124,
#  3.14192,
#  3.14078,
#  3.142964,
#  3.1426,
#  3.141788,
#  3.141848,
#  3.14534,
#  3.143512,
#  3.142776,
#  3.140368,
#  3.142944,
#  3.141476,
#  3.14114,
#  3.145356,
#  3.144944,
#  3.138564,
#  3.145424,
#  3.144944,
#  3.141116,
#  3.140468,
#  3.142616,
#  3.139856,
#  3.144672,
#  3.140752,
#  3.142912,
#  3.141892,
#  3.139144,
#  3.144888,
#  3.139848,
#  3.143852,
#  3.144372,
#  3.142052,
#  3.139388,
#  3.142048,
#  3.144648]

# %%
tab_ref = [compute_pi_on_slice.remote(slice_size=slice_size) for i in range(num_slices)]

# %% [markdown]
# Funkcja ```ray.wait()``` pobiera informacje o gotowych i oczekujących zadaniach na liście

# %%
ready, remaining = ray.wait(tab_ref, num_returns=len(tab_ref), timeout=1)
print(f'------------------- ready -------------------')
print(f'Number of ready tasks: {len(ready)}')
print('---------------------------------------------')
print(f'------------------- remaining -------------------')
print(f'Number of remaining tasks: {len(remaining)}')
# Out:
# ------------------- ready -------------------
# Number of ready tasks: 100
# ---------------------------------------------
# ------------------- remaining -------------------
# Number of remaining tasks: 0

# %%
 print(f'First 5 ready tasks: {ready[:5]}...')
# Out:
# First 5 ready tasks: [ObjectRef(0cf28614706e8724ffffffffffffffffffffffff0100000001000000), ObjectRef(7506e68ad17c8b3fffffffffffffffffffffffff0100000001000000), ObjectRef(56456b5fdef4b4d8ffffffffffffffffffffffff0100000001000000), ObjectRef(a393679f53844a0fffffffffffffffffffffffff0100000001000000), ObjectRef(23a4fa4ccc224d02ffffffffffffffffffffffff0100000001000000)]...

# %% [markdown]
# ## 2. Aktorzy
#
# Cytując: *"Actors extend the Ray API from functions (tasks) to classes. An actor is essentially a stateful worker (or a service). When a new actor is instantiated, a new worker is created, and methods of the actor are scheduled on that specific worker and can access and mutate the state of that worker."*

# %% [markdown]
# ### 2.1 Aktor łączący teksty

# %%
@ray.remote
class Concatenator:
    
    def __init__(self, initial_text=''):
        self.text = initial_text
    
    def append(self, text):
        print(f'[append called] with param: {text}')
        self.text += '\n'
        self.text += text

    def get(self):
        print(f'[get called]')
        return self.text

# wywołanie konstruktora
conc_ref = Concatenator.remote('Lokomotywa') 

# wywołanie zdalnych metod obiektu
conc_ref.append.remote('Stoi na stacji lokomotywa')
conc_ref.append.remote('Ciężka, ogromna i pot z niej spływa -')
conc_ref.append.remote('Tłusta oliwa.') 

text_ref = conc_ref.get.remote()
print(ray.get(text_ref))
# Out:
# Lokomotywa
# Stoi na stacji lokomotywa
# Ciężka, ogromna i pot z niej spływa -
# Tłusta oliwa.

# %% [markdown]
# ### 2.2 Aktor zliczający słowa

# %% [markdown]
# Counter przechowuje informacje o liczbie wystąpień obiektów

# %%
from collections import Counter

counter = Counter()
counter.update([1, 1, 2, 1, 1, 3, 2, 'a', 'a', 'b'])
counter.most_common(3)
# Out:
# [(1, 4), (2, 2), ('a', 2)]

# %% [markdown]
# Wykorzystamy go do policznia wystąpień słów w tekscie

# %%
import requests

url = 'https://wolnelektury.pl/media/book/txt/w-pustyni-i-w-puszczy.txt'
text = requests.get(url).text
words = text.split()

print(f'Ilość wyrazów {len(words)}')
words[:10]
# Out:
# Ilość wyrazów 102265
# ['Henryk',
#  'Sienkiewicz',
#  'W',
#  'pustyni',
#  'i',
#  'w',
#  'puszczy',
#  'ISBN',
#  '978-83-288-2842-1',
#  'ROZDZIAŁ']

# %% [markdown]
# Poprawimy wydzielanie symboli

# %%
from bs4 import BeautifulSoup
import re
import requests

def tokenize(text): 
    text = BeautifulSoup(text, features="html.parser").get_text(' ')
    text = re.sub(r"[#\",!?;-<>/\\*\\&-]", " ", text) #znaki
    text = re.sub('\[[^\]]*\]',' ', text) #
    text = re.sub(r"[:\.\+\=()–©°′″•↑—]", " ", text) #reszta znaków
    text = re.sub(r"\d+\.?\d*", " ", text) #liczby
    words = text.split()
    return words

word_freq = Counter()
url = 'https://wolnelektury.pl/media/book/txt/w-pustyni-i-w-puszczy.txt'

text = requests.get(url).text
words = tokenize(text)
word_freq.update(words)
top_words = word_freq.most_common(10)
top_words
# Out:
# [('i', 3831),
#  ('się', 2739),
#  ('w', 2061),
#  ('na', 1867),
#  ('nie', 1776),
#  ('z', 1705),
#  ('że', 1391),
#  ('do', 1185),
#  ('a', 820),
#  ('to', 757)]

# %%
word_freq.most_common()[-20:-1]
# Out:
# [('Publikacja', 1),
#  ('zrealizowana', 1),
#  ('Reprodukcja', 1),
#  ('cyfrowa', 1),
#  ('Bibliotekę', 1),
#  ('Narodową', 1),
#  ('egzemplarza', 1),
#  ('pochodzącego', 1),
#  ('zbiorów', 1),
#  ('BN', 1),
#  ('Opracowanie', 1),
#  ('redakcyjne', 1),
#  ('Izabela', 1),
#  ('Erdmann', 1),
#  ('Tomasz', 1),
#  ('Jodełka', 1),
#  ('Burzecki', 1),
#  ('Sekuła', 1),
#  ('Olga', 1)]

# %% [markdown]
# Kolejne uaktualnienie

# %%
text = requests.get('https://pl.wikipedia.org/wiki/Polska').text

words = tokenize(text)
word_freq.update(words)
top_words = word_freq.most_common(10)
top_words
# Out:
# [('i', 4579),
#  ('w', 3189),
#  ('się', 2989),
#  ('na', 2208),
#  ('z', 2036),
#  ('nie', 1813),
#  ('że', 1402),
#  ('do', 1387),
#  ('a', 964),
#  ('to', 826)]

# %% [markdown]
# **TODO 2.2.1** Napisz klasę (aktora) ```WordCountingActor``` z metodami:
# * konstruktorem - inicjalizuje atrybut typu ```Counter```
# * tokenize() - wykorzystaj gotową funkcję
# * add_text(self,text:str) - dzieli tekst na słowa i uaktualnia licznik
# * get_top_words(self,n: int) - zwraca n najczęsciej występujących słów

# %%
from collections import Counter
from bs4 import BeautifulSoup
import re

@ray.remote
class WordCountingActor:

    def __init__(self):
        self.word_freq = Counter()

    def tokenize(self, text: str): 
        text = BeautifulSoup(text, features="html.parser").get_text(' ')
        text = BeautifulSoup(text, features="html.parser").get_text(' ')
        text = re.sub(r"[#\",!?;-<>/\\*\\&-]", " ", text)
        text = re.sub('\[[^\]]*\]', ' ', text)
        text = re.sub(r"[:\.\+\=()–©°′″•↑—]", " ", text)
        text = re.sub(r"\d+\.?\d*", " ", text)
        words = text.split()
        return words

    def add_text(self, text: str):
        words = self.tokenize(text)
        self.word_freq.update(words)
    
    def get_top_words(self, n: int):
        return self.word_freq.most_common(n)

# %% [markdown]
# **TODO 2.2.2** Utwórz aktora i dodawaj teksty pobrane ze stron internetowych. Możesz rozszerzyć przykładową listę. Po dodaniu teksty wypisz 10 najczęściej pojawiająych się słów.

# %%
wca_ref = WordCountingActor.remote()

# %%
urls = [
    'https://pl.wikipedia.org/wiki/Akademia_G%C3%B3rniczo-Hutnicza_im._Stanis%C5%82awa_Staszica_w_Krakowie',
    'https://pl.wikipedia.org/wiki/Polska',
    'https://pl.wikipedia.org/wiki/Krak%C3%B3w',
    'https://www.agh.edu.pl/'
]

# %%
for i, url in enumerate(urls):
    text = requests.get(url).text
    wca_ref.add_text.remote(text)
    most_common_words_ref = wca_ref.get_top_words.remote(10)
    print(f'Iteration {i + 1}')
    print(ray.get(most_common_words_ref))
# Out:
# Iteration 1
# [('w', 306), ('i', 237), ('AGH', 162), ('r', 112), ('z', 84), ('prof', 76), ('pol', 71), ('na', 69), ('pl', 64), ('Akademii', 62)]
# Iteration 2
# [('w', 1434), ('i', 985), ('z', 415), ('na', 410), ('się', 295), ('do', 262), ('W', 245), ('Polski', 229), ('%', 206), ('Polsce', 198)]
# Iteration 3
# [('w', 2079), ('i', 1388), ('z', 691), ('na', 616), ('się', 428), ('W', 385), ('do', 370), ('r', 331), ('Polski', 271), ('Kraków', 268)]
# Iteration 4
# [('w', 2087), ('i', 1403), ('z', 696), ('na', 617), ('się', 430), ('W', 385), ('do', 374), ('r', 331), ('Polski', 272), ('Kraków', 268)]

# %% [markdown]
# ## 3. Obiekty (object)
#
# Cytując: *"In Ray, tasks and actors create and compute on objects. We refer to these objects as remote objects because they can be stored anywhere in a Ray cluster, and we use object refs to refer to them. Remote objects are cached in Ray’s distributed shared-memory object store, and there is one object store per node in the cluster. In the cluster setting, a remote object can live on one or many nodes, independent of who holds the object ref(s).*
#
# *An object ref is essentially a pointer or a unique ID that can be used to refer to a remote object without seeing its value. If you’re familiar with futures, Ray object refs are conceptually similar."*
#
# Załadujemy obraz i utworzymy reprezentujący go obiekt

# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = (5, 5)

response = requests.get('https://upload.wikimedia.org/wikipedia/commons/thumb/d/d3/Albert_Einstein_Head.jpg/540px-Albert_Einstein_Head.jpg')
img = Image.open(BytesIO(response.content))
img = np.array(img)

plt.imshow(img, cmap='gray')
plt.show()

# %%
img_ref = ray.put(img)

# %%
img_copy = ray.get(img_ref)
plt.imshow(img_copy, cmap='gray')
plt.show()

# %% [markdown]
# ## 4. Biblioteka  Ray Data i Dataset
# Cytując: *"Ray Data is a scalable data processing library for ML workloads. It provides flexible and performant APIs for scaling Offline batch inference and Data preprocessing and ingest for ML training. Ray Data uses streaming execution to efficiently process large datasets.*
#
# Podstawową klasą jest ```Dataset```. Podobue, jak w przypadku Sparka możliwy jest:
# * odczyt danych z róznych źródeł
# * zapis w róznych formatach
# * podstawowe transformacje (w tym konwersja do Pandas)
# * podział na wsady (batch)
# * automatyczne partycjonowanie i rozkładanie pomiędzy węzły
# * iteracja po pojedynczych danych lub z podziałem na wsady w formatach zgodnych z Tensorflow i Torch

# %%
ds_train = ray.data.read_csv("twitter_training.csv")
ds_test = ray.data.read_csv("twitter_validation.csv")

# %%
ds_train
# Out:
# Dataset(
#    num_rows=74682,
#    schema={
#       TweetId: int64,
#       Entity: string,
#       Sentiment: string,
#       TweetContent: string
#    }
# )

# %%
ds_train.show(5)
# Out:
# 2024-05-23 17:28:49,947	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:28:49,960	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> LimitOperator[limit=5]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - limit=5 2:   0%|                                                                                            …
# Running 0:   0%|                                                                                              …
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'I am coming to the borders and I will kill you all,'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will kill you all,'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im coming on borderlands and i will murder you all,'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands 2 and i will murder you me all,'}

# %%
ds_train.stats()
# Out:
# 'Operator 1 ReadCSV->SplitBlocks(9): 1 tasks executed, 3 blocks produced in 0.57s\n* Remote wall time: 817.99us min, 409.53ms max, 137.06ms mean, 411.18ms total\n* Remote cpu time: 826.4us min, 186.34ms max, 62.73ms mean, 188.19ms total\n* UDF time: 0us min, 0us max, 0.0us mean, 0us total\n* Peak heap memory usage (MiB): 415.8 min, 415.8 max, 415 mean\n* Output num rows per block: 8298 min, 8298 max, 8298 mean, 24894 total\n* Output size bytes per block: 1092359 min, 1257894 max, 1179451 mean, 3538353 total\n* Output rows per task: 24894 min, 24894 max, 24894 mean, 1 tasks used\n* Tasks per node: 1 min, 1 max, 1 mean; 1 nodes used\n* Operator throughput:\n\t* Ray Data throughput: 44029.01395642731 rows/s\n\t* Estimated single node throughput: 60543.34036388655 rows/s\n\nOperator 2 limit=5: 1 tasks executed, 1 blocks produced in 0.41s\n* Remote wall time: 409.53ms min, 409.53ms max, 409.53ms mean, 409.53ms total\n* Remote cpu time: 186.34ms min, 186.34ms max, 186.34ms mean, 186.34ms total\n* UDF time: 0us min, 0us max, 0.0us mean, 0us total\n* Peak heap memory usage (MiB): 415.8 min, 415.8 max, 415 mean\n* Output num rows per block: 5 min, 5 max, 5 mean, 5 total\n* Output size bytes per block: 457 min, 457 max, 457 mean, 457 total\n* Output rows per task: 5 min, 5 max, 5 mean, 1 tasks used\n* Tasks per node: 1 min, 1 max, 1 mean; 1 nodes used\n* Operator throughput:\n\t* Ray Data throughput: 12.20907466040862 rows/s\n\t* Estimated single node throughput: 12.20907466040862 rows/s\n\nDataset iterator time breakdown:\n    * Total time in Ray Data iterator initialization code: 1.44s\n    * Total time user thread is blocked by Ray Data iter_batches: 58.68ms\n    * Total execution time for user thread: 15.07ms\n* Batch iteration time breakdown (summed across prefetch threads):\n    * In ray.get(): 18.57ms min, 18.57ms max, 18.57ms avg, 18.57ms total\n    * In batch creation: 7.51us min, 7.51us max, 7.51us avg, 7.51us total\n    * In batch formatting: 13.13us min, 13.13us max, 13.13us avg, 13.13us total\n\nDataset throughput:\n\t* Ray Data throughput: 8.843298376401405 rows/s\n\t* Estimated single node throughput: 6.092301046337584 rows/s\n'

# %% [markdown]
# ### 4.1 Podstawowe transformacje

# %% [markdown]
# #### to_pandas

# %%
df_train = ds_train.to_pandas()
df_test = ds_test.to_pandas()
df_train.head(10)
# Out:
# Read progress 0:   0%|                                                                                        …
# Read progress 0:   0%|                                                                                        …
# Read progress 0:   0%|                                                                                        …
#    TweetId       Entity Sentiment  \
# 0     2401  Borderlands  Positive
# 1     2401  Borderlands  Positive
# 2     2401  Borderlands  Positive
# 3     2401  Borderlands  Positive
# 4     2401  Borderlands  Positive
# 5     2401  Borderlands  Positive
# 6     2402  Borderlands  Positive
# 7     2402  Borderlands  Positive
# 8     2402  Borderlands  Positive
# 9     2402  Borderlands  Positive
#
#                                         TweetContent
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands 2 and i will murder ...
# 5  im getting into borderlands and i can murder y...
# 6  So I spent a few hours making something for fu...
# 7  So I spent a couple of hours doing something f...
# 8  So I spent a few hours doing something for fun...
# 9  So I spent a few hours making something for fu...

# %% [markdown]
# #### select_columns

# %%
ds2 = ds_train.select_columns(['Entity', 'Sentiment']).show(5)
# Out:
# 2024-05-23 17:28:52,901	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:28:52,903	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[MapBatches(select_columns)] -> LimitOperator[limit=5]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - MapBatches(select_columns) 2:   0%|                                                                         …
# - limit=5 3:   0%|                                                                                            …
# Running 0:   0%|                                                                                              …
# {'Entity': 'Borderlands', 'Sentiment': 'Positive'}
# {'Entity': 'Borderlands', 'Sentiment': 'Positive'}
# {'Entity': 'Borderlands', 'Sentiment': 'Positive'}
# {'Entity': 'Borderlands', 'Sentiment': 'Positive'}
# {'Entity': 'Borderlands', 'Sentiment': 'Positive'}

# %% [markdown]
# #### groupby

# %%
ds2 = ds_train.select_columns(['Entity', 'Sentiment']).groupby(['Entity', 'Sentiment']).count()
# Out:
# 2024-05-23 17:28:54,903	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:28:54,909	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[MapBatches(select_columns)] -> LimitOperator[limit=1]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - MapBatches(select_columns) 2:   0%|                                                                         …
# - limit=1 3:   0%|                                                                                            …
# Running 0:   0%|                                                                                              …

# %%
ds2.to_pandas()
# Out:
# 2024-05-23 17:28:56,481	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:28:56,483	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[MapBatches(select_columns)] -> AllToAllOperator[Aggregate]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - MapBatches(select_columns) 2:   0%|                                                                         …
# - Aggregate 3:   0%|                                                                                          …
# Shuffle Map 4:   0%|                                                                                          …
# Shuffle Reduce 5:   0%|                                                                                       …
# Running 0:   0%|                                                                                              …
# Sort Sample 0:   0%|                                                                                          …
#               Entity   Sentiment  count()
# 0             Amazon  Irrelevant      192
# 1             Amazon    Negative      576
# 2             Amazon     Neutral     1236
# 3             Amazon    Positive      312
# 4        ApexLegends  Irrelevant      192
# ..               ...         ...      ...
# 123    Xbox(Xseries)    Positive      792
# 124  johnson&johnson  Irrelevant      198
# 125  johnson&johnson    Negative      846
# 126  johnson&johnson     Neutral     1014
# 127  johnson&johnson    Positive      270
#
# [128 rows x 3 columns]

# %% [markdown]
# #### filter

# %%
ds2 = ds_train.filter(lambda row: row['Entity'] == 'Nvidia')

# %%
ds2.show(5)
# Out:
# 2024-05-23 17:30:45,377	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:30:45,383	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Filter(<lambda>)] -> LimitOperator[limit=5]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Filter(<lambda>) 2:   0%|                                                                                   …
# - limit=5 3:   0%|                                                                                            …
# Running 0:   0%|                                                                                              …
# {'TweetId': 8801, 'Entity': 'Nvidia', 'Sentiment': 'Neutral', 'TweetContent': 'Interesting NVIDIA=ARM. nvidianews.nvidia.com/news/nvidia-to…'}
# {'TweetId': 8801, 'Entity': 'Nvidia', 'Sentiment': 'Neutral', 'TweetContent': 'Interesting NVIDIA = ARM. nvidianews.nvidia.com / news / nvidia-to...'}
# {'TweetId': 8801, 'Entity': 'Nvidia', 'Sentiment': 'Neutral', 'TweetContent': 'Interesting NVIDIA = ARM. nvidianews.nvidia.com / news / nvidia-to...'}
# {'TweetId': 8801, 'Entity': 'Nvidia', 'Sentiment': 'Neutral', 'TweetContent': 'Interesting NVIDIA=ARM. news.nvidia.com/news/nvidia-to…'}
# {'TweetId': 8801, 'Entity': 'Nvidia', 'Sentiment': 'Neutral', 'TweetContent': 'Information Interesting for NVIDIA = via ARM. nvidianews. nvidia. About com / exclusive news / nvidia - to …'}

# %% [markdown]
# #### map
# Funkcja konwertuje pojedyncze wiersze

# %%
def split_content(row):
    row['words'] = row['TweetContent'].split()
    return row
    
ds_train.map(split_content).show(3)
# Out:
# 2024-05-23 17:30:54,203	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:30:54,216	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(split_content)] -> LimitOperator[limit=3]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(split_content) 2:   0%|                                                                                 …
# - limit=3 3:   0%|                                                                                            …
# Running 0:   0%|                                                                                              …
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'words': ['im', 'getting', 'on', 'borderlands', 'and', 'i', 'will', 'murder', 'you', 'all', ',']}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'I am coming to the borders and I will kill you all,', 'words': ['I', 'am', 'coming', 'to', 'the', 'borders', 'and', 'I', 'will', 'kill', 'you', 'all,']}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will kill you all,', 'words': ['im', 'getting', 'on', 'borderlands', 'and', 'i', 'will', 'kill', 'you', 'all,']}

# %% [markdown]
# **TODO 4.1.1**
# * dodaj kolumnę ```word_count``` zawierającą liczbę słów w ```TweetContent```
# * zgrupuj po kolumnach ```Entity``` i ```Sentiment```
# * za pomocą ```sum(col_name)``` policz ile bylo słów we wpisach należących do danej grupy
# * wyświetl jako ```pandas.DataFrame```

# %%
def count_words(row):
    row['word_count'] = len(row['TweetContent'].split())
    return row
    
ds_train = ds_train.map(count_words)
result = ds_train.groupby(['Entity', 'Sentiment']).sum('word_count')
df_result = result.to_pandas()
df_result.head()
# Out:
# 2024-05-23 17:30:59,998	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:31:00,000	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(count_words)] -> LimitOperator[limit=1]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words) 2:   0%|                                                                                   …
# - limit=1 3:   0%|                                                                                            …
# Running 0:   0%|                                                                                              …
# 2024-05-23 17:31:05,452	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:31:05,454	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(count_words)] -> AllToAllOperator[Aggregate]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words) 2:   0%|                                                                                   …
# - Aggregate 3:   0%|                                                                                          …
# Shuffle Map 4:   0%|                                                                                          …
# Shuffle Reduce 5:   0%|                                                                                       …
# Running 0:   0%|                                                                                              …
# Sort Sample 0:   0%|                                                                                          …
#         Entity   Sentiment  sum(word_count)
# 0       Amazon  Irrelevant             3737
# 1       Amazon    Negative            13030
# 2       Amazon     Neutral            30397
# 3       Amazon    Positive             5715
# 4  ApexLegends  Irrelevant             2527

# %% [markdown]
# #### flat_map
# Funkcja konweruje jeden wiersz na wiele wierszy (analogia do explode)

# %%
def explode_content(row):
    words = row['TweetContent'].split()
    return [{'word': w} for w in words]

ds_train.flat_map(explode_content).show(10)
# Out:
# 2024-05-23 17:31:21,402	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:31:21,404	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(count_words)->FlatMap(explode_content)] -> LimitOperator[limit=10]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words)->FlatMap(explode_content) 2:   0%|                                                         …
# - limit=10 3:   0%|                                                                                           …
# Running 0:   0%|                                                                                              …
# {'word': 'im'}
# {'word': 'getting'}
# {'word': 'on'}
# {'word': 'borderlands'}
# {'word': 'and'}
# {'word': 'i'}
# {'word': 'will'}
# {'word': 'murder'}
# {'word': 'you'}
# {'word': 'all'}

# %% [markdown]
# **TODO 4.1.2** Przepisz funckję ```explode_content()```
#
# W pętli po słowach:
# * utwórz kopię ```row```
# * dodaj słowo (w kolumnie ```word```)
# * dodaj zmodyfikowaną kopię do listy
#
# Zwróć listę

# %%
def explode_content(row):
    words = row['TweetContent'].split()
    rows = []

    for word in words:
        new_row = row.copy()
        new_row['word'] = word
        rows.append(new_row)
        
    return rows

ds_train.flat_map(explode_content).show(10)
# Out:
# 2024-05-23 17:31:31,598	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:31:31,607	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(count_words)->FlatMap(explode_content)] -> LimitOperator[limit=10]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words)->FlatMap(explode_content) 2:   0%|                                                         …
# - limit=10 3:   0%|                                                                                           …
# Running 0:   0%|                                                                                              …
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'im'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'getting'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'on'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'borderlands'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'and'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'i'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'will'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'murder'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'you'}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11, 'word': 'all'}

# %% [markdown]
# #### random_shuffle

# %%
ds_train.random_shuffle(seed=1).to_pandas()
# Out:
# 2024-05-23 17:32:13,620	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:32:13,622	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> AllToAllOperator[Map(count_words)->RandomShuffle]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words)->RandomShuffle 2:   0%|                                                                    …
# Shuffle Map 3:   0%|                                                                                          …
# Shuffle Reduce 4:   0%|                                                                                       …
# Running 0:   0%|                                                                                              …
#        TweetId                             Entity   Sentiment  \
# 0         7779                          MaddenNFL    Negative
# 1         5925                          HomeDepot    Negative
# 2         5649                          HomeDepot    Positive
# 3        10022  PlayerUnknownsBattlegrounds(PUBG)    Negative
# 4         6039                               FIFA    Negative
# ...        ...                                ...         ...
# 74677     6490                           Fortnite  Irrelevant
# 74678    10948               TomClancysGhostRecon    Negative
# 74679     9334                          Overwatch    Positive
# 74680    11965                            Verizon    Negative
# 74681     1698          CallOfDutyBlackopsColdWar  Irrelevant
#
#                                             TweetContent  word_count
# 0      How the hell do you decipher between a 98 and ...          19
# 1      After all, it takes buyers wearing a face mask...          19
# 2                                                     on           1
# 3      I am a Pubg player. I am addicted to Pubg. But...          45
# 4      Game just goes backwards with every patch, how...          11
# ...                                                  ...         ...
# 74677  I know shit and when niggas faithful on fortni...          10
# 74678  And @GhostRecon. THE GHOST TO RECON OR WILDLAN...          23
# 74679                                            Nice...           1
# 74680  @ Verizon YOURE THROTTING OUR SPEEDS??????? SH...          26
# 74681  For children who have not ordered a pre-order....           8
#
# [74682 rows x 5 columns]

# %% [markdown]
# #### iteratory (w tym dzielące na wsady: batch)

# %%
for i, row in enumerate(ds_train.iter_rows()):
    if i == 3:
        break
    print(row)
# Out:
# 2024-05-23 17:32:24,521	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:32:24,529	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(count_words)]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words) 2:   0%|                                                                                   …
# Running 0:   0%|                                                                                              …
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will murder you all ,', 'word_count': 11}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'I am coming to the borders and I will kill you all,', 'word_count': 12}
# {'TweetId': 2401, 'Entity': 'Borderlands', 'Sentiment': 'Positive', 'TweetContent': 'im getting on borderlands and i will kill you all,', 'word_count': 10}

# %%
for i, row in enumerate(ds_train.iter_batches(batch_size=2)):
    if i == 3:
        break
    print('-------------')    
    print(row)
# Out:
# 2024-05-23 17:32:29,282	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 17:32:29,299	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> TaskPoolMapOperator[Map(count_words)]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Map(count_words) 2:   0%|                                                                                   …
# Running 0:   0%|                                                                                              …
# -------------
# {'TweetId': array([2401, 2401]), 'Entity': array(['Borderlands', 'Borderlands'], dtype=object), 'Sentiment': array(['Positive', 'Positive'], dtype=object), 'TweetContent': array(['im getting on borderlands and i will murder you all ,',
#        'I am coming to the borders and I will kill you all,'],
#       dtype=object), 'word_count': array([11, 12])}
# -------------
# {'TweetId': array([2401, 2401]), 'Entity': array(['Borderlands', 'Borderlands'], dtype=object), 'Sentiment': array(['Positive', 'Positive'], dtype=object), 'TweetContent': array(['im getting on borderlands and i will kill you all,',
#        'im coming on borderlands and i will murder you all,'],
#       dtype=object), 'word_count': array([10, 10])}
# -------------
# {'TweetId': array([2401, 2401]), 'Entity': array(['Borderlands', 'Borderlands'], dtype=object), 'Sentiment': array(['Positive', 'Positive'], dtype=object), 'TweetContent': array(['im getting on borderlands 2 and i will murder you me all,',
#        'im getting into borderlands and i can murder you all,'],
#       dtype=object), 'word_count': array([12, 10])}

# %% [markdown]
# ## 5. Klasyfikacja

# %% [markdown]
# ### 5.1 Metryki

# %% [markdown]
# **TODO 5.1.1** napisz funkcję, która oblicza i zwraca metryki lub raport klasyfikacji

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

@ray.remote
def get_classification_results(y_true, y_pred, labels=None, return_scores=True):
    """
    Funkcja oblicza wetryki klasyfikacji
    Jeżeli return_scores==True funkcja zwraca słownik zawierający wartości accuracy, precision, recall (w wersji macro)
    Jeżeli return_scores==False funcka zwraca tekst będący wynikiem wywołania classification_report (z etykietami klas)
    """
    if return_scores:
        acc = accuracy_score(y_true, y_pred)
        precision = precision_score(y_true, y_pred, average='macro', zero_division=0)
        recall = recall_score(y_true, y_pred, average='macro', zero_division=0)
        f1 = f1_score(y_true, y_pred, average='macro', zero_division=0)
        return { 'accuracy': acc, 'precision': precision, 'recall': recall, 'f1-score': f1 }
    else:
        return classification_report(y_true, y_pred)

# %%
results_ref = get_classification_results.remote([1,1,2,2,3,3], [1,1,2,1,3,3], labels=['a','b','c'])
ray.get(results_ref)
# Out:
# {'accuracy': 0.8333333333333334,
#  'precision': 0.8888888888888888,
#  'recall': 0.8333333333333334,
#  'f1-score': 0.8222222222222223}

# %%
results_ref = get_classification_results.remote([1,1,2,2,3,3], [1,1,2,1,3,3], labels=['a','b','c'], return_scores=False)
print(ray.get(results_ref))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.67      1.00      0.80         2
#            2       1.00      0.50      0.67         2
#            3       1.00      1.00      1.00         2
#
#     accuracy                           0.83         6
#    macro avg       0.89      0.83      0.82         6
# weighted avg       0.89      0.83      0.82         6

# %% [markdown]
# ### 5.2 train_and_test

# %% [markdown]
# **TODO 5.2.1** Napisz funckję zgodnie ze specyfikacją

# %%
from sklearn import preprocessing

@ray.remote
def train_and_test(df_train, df_test, model, features_column, target_column, return_scores=True):
    """
    Funkcja (1) stosuje preprocessing.LabelEncoder() dla zbudowania wektorów liczbowych etykiet y_train oraz y_test
    (2) przeprowadza uczenie modelu
    (3) wyznacza wartości przewidywanych etykiet dla zbioru treningowego i testowego
    (4) wyznacza metryki predykcji dla zbioru uczącego i testowego wywołując get_classification_results
    
    Params: df_train - zbiór treningowy
            df_test  - zbiór testowy
            model - model klasyfikatora (algorytm) 
            features_column - kolumna zawierająca cechy
            target_column - kolumna z etykietami
            return_scores - analogicznie, jak get_classification_results
    Returns:
            Słownik zawierający następujące elementy
            * 'train' - metryki dla zbioru treningowego
            * 'test' - metryki dla zbioru uczącego
            * 'model' - wytrenowany model
            * 'labels' - etykiety
    """

    le = preprocessing.LabelEncoder()

    X_train, y_train = df_train[features_column], le.fit_transform(df_train[target_column])
    X_test, y_test = df_test[features_column], le.transform(df_test[target_column])
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_metrics = get_classification_results.remote(y_train, y_train_pred, return_scores=return_scores)
    test_metrics = get_classification_results.remote(y_test, y_test_pred, return_scores=return_scores)

    return { 'train': train_metrics, 'test': test_metrics, 'model': model, 'labels': le.classes_ }

# %% [markdown]
# ### 5.3 Wywołanie

# %%
ds_train = ray.data.read_csv("twitter_training.csv")
ds_test = ray.data.read_csv("twitter_validation.csv")
df_train = ds_train.to_pandas()
df_test = ds_test.to_pandas()
df_train_ref = ray.put(df_train)
df_test_ref = ray.put(df_test)
# Out:
# Read progress 0:   0%|                                                                                        …
# Read progress 0:   0%|                                                                                        …
# Read progress 0:   0%|                                                                                        …
# Read progress 0:   0%|                                                                                        …

# %% [markdown]
# **TODO 5.3.1** Wywołaj funkcję przekazując referencje do odpowiednich obiektów Ray

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier

X, y = 'TweetContent', 'Sentiment'
pipeline = Pipeline([('vect', CountVectorizer()), ('cls', MultinomialNB())])
results_ref = train_and_test.remote(df_train_ref, df_test_ref, pipeline, X, y)

# %%
results = ray.get(results_ref)

# %%
ray.get(results['train'])
# Out:
# {'accuracy': 0.7963766369406282,
#  'precision': 0.819132108265895,
#  'recall': 0.7831437089896423,
#  'f1-score': 0.7935849161197497}

# %%
ray.get(results['test'])
# Out:
# {'accuracy': 0.825,
#  'precision': 0.8389426103407482,
#  'recall': 0.8178315799363239,
#  'f1-score': 0.8230766650524841}

# %% [markdown]
# **TODO 5.3.2** Wywołaj funkcję dla innego klasyfikatora i odczytaj wyniki

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline

pipeline = Pipeline([('vect', CountVectorizer()), ('cls', SGDClassifier(loss='perceptron', penalty='l2', alpha=1e-3))])
results_ref = train_and_test.remote(df_train_ref, df_test_ref, pipeline, X, y)

# %%
results = ray.get(results_ref)

# %%
ray.get(results['train'])
# Out:
# {'accuracy': 0.8876436089017434,
#  'precision': 0.8894081971768011,
#  'recall': 0.884958538487503,
#  'f1-score': 0.8870380020033943}

# %%
ray.get(results['test'])
# Out:
# {'accuracy': 0.926,
#  'precision': 0.9259781662888762,
#  'recall': 0.9265363160230354,
#  'f1-score': 0.9262398866951566}

# %% [markdown]
# ## 6. Walidacja krzyżowa

# %% [markdown]
# **TODO 6.1.1** Napisz funkcję zgodnie ze specyfikacją.
#
# Będzie realizowała pojedyncze zadanie wywoływane podczas walidacji krzyżowej (uczenie na k-1 podzbiorach, testowanie na jednym pozostawionym podzbiorze).
# * Te zadania można zrównoleglić.
# * Zbiór, na którym będzie wykonywana walidacja krzyżowa będzie obiektem
# * Zadania będą wywoływane z róznymi zestawami indeksów odpowiadającymi podziałowi na podzbiory (*ang. fold*) uzyte do budowy modelu i testowania

# %%
@ray.remote
def train_and_test_fold(df, train_indexes, test_indexes, model, features_column, target_column, return_scores=True):
    """
    Funkcja
    (1) dzieli zbiór na podzbiór dt_train treningowy i df_test testowy na podstawie indeksów wierszy 
    (2) stosuje preprocessing.LabelEncoder() dla zbudowania wektorów liczbowych etykiet y_train oraz y_test
    (3) przeprowadza uczenie modelu
    (4) wyznacza wartości przewidywanych etykiet dla zbioru treningowego i testowego
    (5) wyznacza metryki predykcji dla zbioru uczącego i testowego wywołując get_classification_results
    
    Params: df - zbiór poddany walidacji krzyżowej 
            train_indexes - indeksy wierszy podzbioru treningowego (z 
            test_indexes  - indeksy wierszy podzbioru testowego
            model - model klasyfikatora (algorytm) 
            features_column - kolumna zawierająca cechy
            target_column - kolumna z etykietami
            return_scores - analogicznie, jak get_classification_results
    Returns:
            Słownik zawierający następujące elementy
            * 'train' - metryki dla zbioru treningowego
            * 'test' - metryki dla zbioru uczącego
            * 'model' - wytrenowany model
            * 'labels' - etykiety
    """

    df_train = df.iloc[train_indexes]
    df_test = df.iloc[test_indexes]

    le = preprocessing.LabelEncoder()

    X_train, y_train = df_train[features_column], le.fit_transform(df_train[target_column])
    X_test, y_test = df_test[features_column], le.transform(df_test[target_column])
    model.fit(X_train, y_train)

    y_train_pred = model.predict(X_train)
    y_test_pred = model.predict(X_test)

    train_metrics = get_classification_results.remote(y_train, y_train_pred, return_scores=return_scores)
    test_metrics = get_classification_results.remote(y_test, y_test_pred, return_scores=return_scores)

    return { 'train': train_metrics, 'test': test_metrics, 'model': model, 'labels': le.classes_ }

# %% [markdown]
# Przykład funkcji realizującej walidację krzyzową ze stratyfikacją (podziałem zachowującym prawdopodobieństwo a-priori klas)

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.base import clone

@ray.remote
def cross_validate_stratified(df, model, features_column, target_column, n_splits=10):
    skf = StratifiedKFold(n_splits=n_splits)
    result_refs=[]
    
    for i, (train_indexes, test_indexes) in enumerate(skf.split(df_train, df_train[target_column])):
        result_refs.append(train_and_test_fold.remote(df_train, train_indexes, test_indexes, clone(model), features_column, target_column))
        
    return result_refs

# %% [markdown]
# **TODO 6.1.2** napisz analogiczną funkcję bez startyfikacji, posługująca się klasa ```KFold```

# %%
from sklearn.model_selection import KFold
from sklearn.base import clone

@ray.remote
def cross_validate_kfold(df, model, features_column, target_column, n_splits=10):
    kf = KFold(n_splits=n_splits)
    result_refs = []
    
    for i, (train_indexes, test_indexes) in enumerate(kf.split(df)):
        result_refs.append(train_and_test_fold.remote(df, train_indexes, test_indexes, clone(model), features_column, target_column))
        
    return result_refs

# %%
pipeline = Pipeline([('vect', CountVectorizer()), ('cls', SGDClassifier(loss='perceptron', penalty='l2', alpha=1e-3))])

results_ref = cross_validate_stratified.remote(
    df_train_ref, 
    pipeline,
    features_column='TweetContent', 
    target_column='Sentiment'
)

# %% [markdown]
# **TODO 6.1.3** Odczytaj wyniki

# %%
results = ray.get(results_ref)
fold_results = ray.get(results)

for i, result in enumerate(fold_results):
    print(f"Results from fold {i + 1}:")

    train_results = ray.get(result['train'])
    test_results = ray.get(result['test'])

    train_metrics_str, test_metrics_str = "", ""

    for metric, value in train_results.items():
        train_metrics_str += f"{metric}: {value:.3f}, "

    for metric, value in test_results.items():
        test_metrics_str += f"{metric}: {value:.3f}, "
        
    print("Train Performance Metrics: ", train_metrics_str)
    print("Test Performance Metrics: ", test_metrics_str)
    print("---------------------------------------------------")
# Out:
# Results from fold 1:
# Train Performance Metrics:  accuracy: 0.893, precision: 0.893, recall: 0.892, f1-score: 0.892,
# Test Performance Metrics:  accuracy: 0.428, precision: 0.424, recall: 0.419, f1-score: 0.415,
# ---------------------------------------------------
# Results from fold 2:
# Train Performance Metrics:  accuracy: 0.892, precision: 0.893, recall: 0.891, f1-score: 0.891,
# Test Performance Metrics:  accuracy: 0.418, precision: 0.438, recall: 0.408, f1-score: 0.406,
# ---------------------------------------------------
# Results from fold 3:
# Train Performance Metrics:  accuracy: 0.882, precision: 0.884, recall: 0.879, f1-score: 0.881,
# Test Performance Metrics:  accuracy: 0.361, precision: 0.343, recall: 0.344, f1-score: 0.341,
# ---------------------------------------------------
# Results from fold 4:
# Train Performance Metrics:  accuracy: 0.897, precision: 0.897, recall: 0.895, f1-score: 0.896,
# Test Performance Metrics:  accuracy: 0.356, precision: 0.347, recall: 0.347, f1-score: 0.347,
# ---------------------------------------------------
# Results from fold 5:
# Train Performance Metrics:  accuracy: 0.889, precision: 0.888, recall: 0.888, f1-score: 0.888,
# Test Performance Metrics:  accuracy: 0.361, precision: 0.353, recall: 0.358, f1-score: 0.354,
# ---------------------------------------------------
# Results from fold 6:
# Train Performance Metrics:  accuracy: 0.887, precision: 0.890, recall: 0.884, f1-score: 0.886,
# Test Performance Metrics:  accuracy: 0.251, precision: 0.260, recall: 0.244, f1-score: 0.248,
# ---------------------------------------------------
# Results from fold 7:
# Train Performance Metrics:  accuracy: 0.896, precision: 0.898, recall: 0.895, f1-score: 0.896,
# Test Performance Metrics:  accuracy: 0.200, precision: 0.189, recall: 0.190, f1-score: 0.186,
# ---------------------------------------------------
# Results from fold 8:
# Train Performance Metrics:  accuracy: 0.887, precision: 0.893, recall: 0.884, f1-score: 0.888,
# Test Performance Metrics:  accuracy: 0.311, precision: 0.301, recall: 0.292, f1-score: 0.288,
# ---------------------------------------------------
# Results from fold 9:
# Train Performance Metrics:  accuracy: 0.884, precision: 0.884, recall: 0.885, f1-score: 0.882,
# Test Performance Metrics:  accuracy: 0.375, precision: 0.369, recall: 0.359, f1-score: 0.344,
# ---------------------------------------------------
# Results from fold 10:
# Train Performance Metrics:  accuracy: 0.889, precision: 0.889, recall: 0.889, f1-score: 0.888,
# Test Performance Metrics:  accuracy: 0.397, precision: 0.400, recall: 0.385, f1-score: 0.386,
# ---------------------------------------------------

# %% [markdown]
# **TODO 6.1.4** Wywołaj funkcję ```cross_validate()``` i odczytaj wyniki

# %%
pipeline = Pipeline([('vect', CountVectorizer()), ('cls', SGDClassifier(loss='perceptron', penalty='l2', alpha=1e-3))])

results_ref = cross_validate_kfold.remote(
    df_train_ref, 
    pipeline,
    features_column='TweetContent', 
    target_column='Sentiment'
)

# %%
results = ray.get(results_ref)
fold_results = ray.get(results)

for i, result in enumerate(fold_results):
    print(f"Results from fold {i + 1}:")

    train_results = ray.get(result['train'])
    test_results = ray.get(result['test'])

    train_metrics_str, test_metrics_str = "", ""

    for metric, value in train_results.items():
        train_metrics_str += f"{metric}: {value:.3f}, "

    for metric, value in test_results.items():
        test_metrics_str += f"{metric}: {value:.3f}, "
        
    print("Train Performance Metrics: ", train_metrics_str)
    print("Test Performance Metrics: ", test_metrics_str)
    print("---------------------------------------------------")
# Out:
# Results from fold 1:
# Train Performance Metrics:  accuracy: 0.896, precision: 0.897, recall: 0.896, f1-score: 0.896,
# Test Performance Metrics:  accuracy: 0.454, precision: 0.433, recall: 0.428, f1-score: 0.429,
# ---------------------------------------------------
# Results from fold 2:
# Train Performance Metrics:  accuracy: 0.884, precision: 0.879, recall: 0.886, f1-score: 0.881,
# Test Performance Metrics:  accuracy: 0.442, precision: 0.426, recall: 0.417, f1-score: 0.417,
# ---------------------------------------------------
# Results from fold 3:
# Train Performance Metrics:  accuracy: 0.881, precision: 0.881, recall: 0.881, f1-score: 0.880,
# Test Performance Metrics:  accuracy: 0.397, precision: 0.391, recall: 0.395, f1-score: 0.386,
# ---------------------------------------------------
# Results from fold 4:
# Train Performance Metrics:  accuracy: 0.887, precision: 0.886, recall: 0.886, f1-score: 0.886,
# Test Performance Metrics:  accuracy: 0.387, precision: 0.390, recall: 0.389, f1-score: 0.382,
# ---------------------------------------------------
# Results from fold 5:
# Train Performance Metrics:  accuracy: 0.890, precision: 0.894, recall: 0.887, f1-score: 0.889,
# Test Performance Metrics:  accuracy: 0.407, precision: 0.401, recall: 0.401, f1-score: 0.398,
# ---------------------------------------------------
# Results from fold 6:
# Train Performance Metrics:  accuracy: 0.891, precision: 0.895, recall: 0.887, f1-score: 0.890,
# Test Performance Metrics:  accuracy: 0.380, precision: 0.386, recall: 0.379, f1-score: 0.370,
# ---------------------------------------------------
# Results from fold 7:
# Train Performance Metrics:  accuracy: 0.894, precision: 0.895, recall: 0.892, f1-score: 0.893,
# Test Performance Metrics:  accuracy: 0.413, precision: 0.383, recall: 0.382, f1-score: 0.376,
# ---------------------------------------------------
# Results from fold 8:
# Train Performance Metrics:  accuracy: 0.885, precision: 0.893, recall: 0.882, f1-score: 0.886,
# Test Performance Metrics:  accuracy: 0.475, precision: 0.440, recall: 0.443, f1-score: 0.436,
# ---------------------------------------------------
# Results from fold 9:
# Train Performance Metrics:  accuracy: 0.870, precision: 0.876, recall: 0.867, f1-score: 0.870,
# Test Performance Metrics:  accuracy: 0.478, precision: 0.442, recall: 0.448, f1-score: 0.436,
# ---------------------------------------------------
# Results from fold 10:
# Train Performance Metrics:  accuracy: 0.886, precision: 0.890, recall: 0.882, f1-score: 0.885,
# Test Performance Metrics:  accuracy: 0.455, precision: 0.420, recall: 0.421, f1-score: 0.412,
# ---------------------------------------------------

# %% [markdown]
# ## 7. Modele dla Entity

# %% [markdown]
# Spróbujemy zbudować indywidaualne klasyfikatory dla ocenianych obiektów *Entity*

# %%
df_train.Entity.unique()
# Out:
# array(['Borderlands', 'CallOfDutyBlackopsColdWar', 'Amazon', 'Overwatch',
#        'Xbox(Xseries)', 'NBA2K', 'Dota2', 'PlayStation5(PS5)',
#        'WorldOfCraft', 'CS-GO', 'Google', 'AssassinsCreed', 'ApexLegends',
#        'LeagueOfLegends', 'Fortnite', 'Microsoft', 'Hearthstone',
#        'Battlefield', 'PlayerUnknownsBattlegrounds(PUBG)', 'Verizon',
#        'HomeDepot', 'FIFA', 'RedDeadRedemption(RDR)', 'CallOfDuty',
#        'TomClancysRainbowSix', 'Facebook', 'GrandTheftAuto(GTA)',
#        'MaddenNFL', 'johnson&johnson', 'Cyberpunk2077',
#        'TomClancysGhostRecon', 'Nvidia'], dtype=object)

# %% [markdown]
# **TODO 7.1.1** W petli po podzbiorach danych:
# * utwórz Pipeline
# * wywołaj funkcję ```train_and_test()```
# * umieść wyniki (classification_report) w słowniku konwerując nazwę obiektu na małe litery
# * wyświetl wyniki dla testów

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.linear_model import SGDClassifier

results = {}

for ent in df_train.Entity.unique():
    pipeline = Pipeline([('vect', CountVectorizer()), ('cls', SGDClassifier(loss='perceptron', penalty='l2', alpha=1e-3))])

    df_train_ent = df_train[df_train['Entity'] == ent]
    df_test_ent = df_test[df_test['Entity'] == ent]

    result_ref = train_and_test.remote(df_train_ent, df_test_ent, pipeline, features_column='TweetContent', target_column='Sentiment')
    result = ray.get(result_ref)

    result['train'] = ray.get(result['train'])
    result['test'] = ray.get(result['test'])
    results[ent.lower()] = result

# %%
for entity, result in results.items():
    print(f'-------------- {entity} ------------')
    train_metrics_str, test_metrics_str = "", ""
    
    for metric, value in result['train'].items():
        train_metrics_str += f'{metric}: {value:.3f}, '
    
    for metric, value in result['test'].items():
        test_metrics_str += f'{metric}: {value:.3f}, '

    print('Train metrics: ', train_metrics_str)
    print('Test metrics: ', test_metrics_str)
    print('-----------------------------------')
# Out:
# -------------- borderlands ------------
# Train metrics:  accuracy: 0.984, precision: 0.988, recall: 0.982, f1-score: 0.985,
# Test metrics:  accuracy: 0.970, precision: 0.983, recall: 0.979, f1-score: 0.981,
# -----------------------------------
# -------------- callofdutyblackopscoldwar ------------
# Train metrics:  accuracy: 0.955, precision: 0.959, recall: 0.955, f1-score: 0.955,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- amazon ------------
# Train metrics:  accuracy: 0.983, precision: 0.989, recall: 0.971, f1-score: 0.980,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- overwatch ------------
# Train metrics:  accuracy: 0.973, precision: 0.962, recall: 0.974, f1-score: 0.967,
# Test metrics:  accuracy: 0.938, precision: 0.956, recall: 0.902, f1-score: 0.922,
# -----------------------------------
# -------------- xbox(xseries) ------------
# Train metrics:  accuracy: 0.981, precision: 0.986, recall: 0.978, f1-score: 0.982,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- nba2k ------------
# Train metrics:  accuracy: 0.985, precision: 0.987, recall: 0.973, f1-score: 0.980,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- dota2 ------------
# Train metrics:  accuracy: 0.986, precision: 0.988, recall: 0.987, f1-score: 0.987,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- playstation5(ps5) ------------
# Train metrics:  accuracy: 0.971, precision: 0.982, recall: 0.966, f1-score: 0.973,
# Test metrics:  accuracy: 0.939, precision: 0.971, recall: 0.937, f1-score: 0.950,
# -----------------------------------
# -------------- worldofcraft ------------
# Train metrics:  accuracy: 0.991, precision: 0.994, recall: 0.985, f1-score: 0.990,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- cs-go ------------
# Train metrics:  accuracy: 0.974, precision: 0.979, recall: 0.971, f1-score: 0.974,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- google ------------
# Train metrics:  accuracy: 0.982, precision: 0.984, recall: 0.981, f1-score: 0.982,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- assassinscreed ------------
# Train metrics:  accuracy: 0.991, precision: 0.996, recall: 0.982, f1-score: 0.989,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- apexlegends ------------
# Train metrics:  accuracy: 0.970, precision: 0.979, recall: 0.970, f1-score: 0.974,
# Test metrics:  accuracy: 0.972, precision: 0.938, recall: 0.975, f1-score: 0.951,
# -----------------------------------
# -------------- leagueoflegends ------------
# Train metrics:  accuracy: 0.973, precision: 0.978, recall: 0.970, f1-score: 0.974,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- fortnite ------------
# Train metrics:  accuracy: 0.978, precision: 0.981, recall: 0.968, f1-score: 0.974,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- microsoft ------------
# Train metrics:  accuracy: 0.972, precision: 0.966, recall: 0.967, f1-score: 0.966,
# Test metrics:  accuracy: 0.929, precision: 0.938, recall: 0.964, f1-score: 0.945,
# -----------------------------------
# -------------- hearthstone ------------
# Train metrics:  accuracy: 0.976, precision: 0.983, recall: 0.975, f1-score: 0.979,
# Test metrics:  accuracy: 0.969, precision: 0.977, recall: 0.975, f1-score: 0.975,
# -----------------------------------
# -------------- battlefield ------------
# Train metrics:  accuracy: 0.974, precision: 0.975, recall: 0.968, f1-score: 0.971,
# Test metrics:  accuracy: 0.962, precision: 0.981, recall: 0.964, f1-score: 0.971,
# -----------------------------------
# -------------- playerunknownsbattlegrounds(pubg) ------------
# Train metrics:  accuracy: 0.960, precision: 0.974, recall: 0.953, f1-score: 0.963,
# Test metrics:  accuracy: 0.974, precision: 0.977, recall: 0.983, f1-score: 0.979,
# -----------------------------------
# -------------- verizon ------------
# Train metrics:  accuracy: 0.984, precision: 0.978, recall: 0.975, f1-score: 0.976,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- homedepot ------------
# Train metrics:  accuracy: 0.983, precision: 0.987, recall: 0.981, f1-score: 0.984,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- fifa ------------
# Train metrics:  accuracy: 0.981, precision: 0.989, recall: 0.969, f1-score: 0.978,
# Test metrics:  accuracy: 0.947, precision: 0.954, recall: 0.906, f1-score: 0.925,
# -----------------------------------
# -------------- reddeadredemption(rdr) ------------
# Train metrics:  accuracy: 0.981, precision: 0.987, recall: 0.976, f1-score: 0.981,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- callofduty ------------
# Train metrics:  accuracy: 0.982, precision: 0.984, recall: 0.977, f1-score: 0.981,
# Test metrics:  accuracy: 0.903, precision: 0.908, recall: 0.932, f1-score: 0.910,
# -----------------------------------
# -------------- tomclancysrainbowsix ------------
# Train metrics:  accuracy: 0.961, precision: 0.968, recall: 0.963, f1-score: 0.964,
# Test metrics:  accuracy: 0.971, precision: 0.982, recall: 0.979, f1-score: 0.980,
# -----------------------------------
# -------------- facebook ------------
# Train metrics:  accuracy: 0.980, precision: 0.982, recall: 0.974, f1-score: 0.978,
# Test metrics:  accuracy: 0.939, precision: 0.950, recall: 0.950, f1-score: 0.950,
# -----------------------------------
# -------------- grandtheftauto(gta) ------------
# Train metrics:  accuracy: 0.977, precision: 0.977, recall: 0.971, f1-score: 0.974,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- maddennfl ------------
# Train metrics:  accuracy: 0.989, precision: 0.983, recall: 0.980, f1-score: 0.982,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- johnson&johnson ------------
# Train metrics:  accuracy: 0.991, precision: 0.991, recall: 0.989, f1-score: 0.990,
# Test metrics:  accuracy: 1.000, precision: 1.000, recall: 1.000, f1-score: 1.000,
# -----------------------------------
# -------------- cyberpunk2077 ------------
# Train metrics:  accuracy: 0.971, precision: 0.978, recall: 0.967, f1-score: 0.972,
# Test metrics:  accuracy: 0.967, precision: 0.875, recall: 0.985, f1-score: 0.909,
# -----------------------------------
# -------------- tomclancysghostrecon ------------
# Train metrics:  accuracy: 0.979, precision: 0.974, recall: 0.975, f1-score: 0.974,
# Test metrics:  accuracy: 0.909, precision: 0.847, recall: 0.861, f1-score: 0.852,
# -----------------------------------
# -------------- nvidia ------------
# Train metrics:  accuracy: 0.979, precision: 0.986, recall: 0.978, f1-score: 0.982,
# Test metrics:  accuracy: 0.971, precision: 0.977, recall: 0.983, f1-score: 0.979,
# -----------------------------------

# %% [markdown]
# **TODO 7.1.2** Doaj jeszcze do słownika wyniki dla pełnego zbioru (pod kluczem ```*```)

# %%
pipeline = Pipeline([('vect', CountVectorizer()), ('cls', SGDClassifier(loss='perceptron', penalty='l2', alpha=1e-3))])
full_result_ref = train_and_test.remote(df_train, df_test, pipeline, features_column='TweetContent', target_column='Sentiment', return_scores=False)

full_result = ray.get(full_result_ref)
full_result['train'] = ray.get(full_result['train'])
full_result['test'] = ray.get(full_result['test'])
results['*'] = full_result

# %% [markdown]
# **TODO 7.1.3** Wyekstrahuj z rezuultatów dwa słowniki: ```models```  z modelami oraz ```labels``` z etykietami.
#
# Etykiety występują zawsze w tej samej kolejności, ale to specyfika zbioru danych. Gdyby zastosować permutację, przed uczeniem, kolejność byłaby inna, więc *better save than sorry...*

# %%
models, labels = {}, {}

# Idk...
for entity, result in results.items():
    models[entity] = result['model']
    labels[entity] = result['labels']

# %% [markdown]
# Poniższa funkcja dokonuje klasyfikacji tekstu dla danego typu obiektu (entity). Jesli nie zostanie znaleziony, stosuje klucz ```*```
#
# Wypróbuj jej działanie wpisując rózne wartości...

# %%
def classify(models, labels, ent, text):
    k = ent.lower()
    if not k in models:
        k = '*'
    y_pred =  models[k].predict([text])
    return labels[k][y_pred[0]]
    
classify(models, labels, '*', 'low energy card')
# Out:
# 'Neutral'

# %%
classify(models, labels, 'nvidia', 'low energy card')
# Out:
# 'Positive'

# %% [markdown]
# ## 8. Ray serve

# %% [markdown]
# Ray Serve to framework do zarządzania mikrousługami, który został stworzony na platformie Ray. Pozwala on na łatwe tworzenie, wdrażanie i skalowanie aplikacji opartych na mikrousługach.
#
# Cechy:
#
# * **Prostota użycia:** Ray Serve zapewnia proste API do definiowania i wdrażania mikrousług. Programiści mogą definiować obsługę żądań za pomocą zwykłych funkcji Pythona.
# * **Elastyczność i skalowalność:** Ray Serve automatycznie zarządza skalowaniem i równoważeniem obciążenia mikrousług, co umożliwia obsługę wysokiego obciążenia aplikacji.
# * **Obsługa wielu typów modeli:** Ray Serve obsługuje wiele rodzajów modeli, w tym modele oparte na frameworkach uczenia maszynowego, takich jak TensorFlow, PyTorch czy Scikit-learn.
# * **Obsługa wielu typów interfejsów:** Obsługuje różne interfejsy API, takie jak REST, gRPC, HTTP oraz in-memory Python API, co umożliwia łatwe integrowanie z różnymi typami aplikacji.
# * **Rozproszenie i równoległość:** Dzięki wykorzystaniu platformy Ray, Ray Serve oferuje wbudowane wsparcie dla równoległego przetwarzania i rozproszenia, co pozwala na obsługę wysokich obciążeń i dużych ilości danych.

# %%
from ray import serve
# serve.shutdown()
serve.start(http_options={'host':'0.0.0.0', 'port':8000})

# %% [markdown]
# ### 8.1 Przykład wdrożenia mikrousługi

# %% [markdown]
# Pokazemy prosty przykład usług REST. Dzięki (opcjonalnej) integracji z FastApi możliwe będzie wywołanie poprzez interfejs *Swagger*

# %%
import requests
from fastapi import FastAPI
from ray import serve
# import uvicorn

# 1: Define a FastAPI app and wrap it in a deployment with a route handler.
app = FastAPI()

@serve.deployment
@serve.ingress(app)
class FastAPIDeployment:
    # FastAPI will automatically parse the HTTP request for us.
    @app.get("/hello")
    def say_hello(self, firstname: str, surname: str) -> str:
        return f"Hello {firstname} {surname}!"


# 2: Deploy the deployment.
# serve.shutdown()
# serve.start(http_options={'host':'0.0.0.0','port':8000})
serve.run(FastAPIDeployment.bind(), route_prefix="/")

# otwórz http://localhost:8000/docs
# Out:
# The new client HTTP config differs from the existing one in the following fields: ['host', 'location']. The new HTTP config is ignored.
# 2024-05-23 17:56:39,806	INFO handle.py:126 -- Created DeploymentHandle 'kc2td5fa' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:39,810	INFO handle.py:126 -- Created DeploymentHandle 'cqs8gu4z' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,883	INFO handle.py:126 -- Created DeploymentHandle 'awau1tsq' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,884	INFO api.py:584 -- Deployed app 'default' successfully.
# 2024-05-23 17:56:45,913	INFO handle.py:126 -- Created DeploymentHandle 'f57mb22i' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,915	INFO handle.py:126 -- Created DeploymentHandle 'n8wsphhb' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,918	INFO handle.py:126 -- Created DeploymentHandle 'g2zdvot4' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,920	INFO handle.py:126 -- Created DeploymentHandle '6119b8zc' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,926	INFO handle.py:126 -- Created DeploymentHandle '92rzd4bx' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,927	INFO handle.py:126 -- Created DeploymentHandle '3ts7pp9d' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,931	INFO handle.py:126 -- Created DeploymentHandle 'fgtwmk9t' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,949	INFO handle.py:126 -- Created DeploymentHandle 'ioo5mi77' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,952	INFO pow_2_scheduler.py:260 -- Got updated replicas for Deployment(name='FastAPIDeployment', app='default'): {'u6madcuv'}.
# 2024-05-23 17:56:45,958	INFO handle.py:126 -- Created DeploymentHandle '0odha8oe' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,976	INFO handle.py:126 -- Created DeploymentHandle '72dxxj0g' for Deployment(name='FastAPIDeployment', app='default').
# 2024-05-23 17:56:45,978	INFO handle.py:126 -- Created DeploymentHandle 'ye5zczdx' for Deployment(name='FastAPIDeployment', app='default').
# DeploymentHandle(deployment='FastAPIDeployment')
# 2024-05-23 18:07:36,541	INFO pow_2_scheduler.py:260 -- Got updated replicas for Deployment(name='FastAPIDeployment', app='default'): set().
# 2024-05-23 18:08:02,704	INFO pow_2_scheduler.py:260 -- Got updated replicas for Deployment(name='ClassifierDeployment', app='default'): {'wqhraob9'}.

# %%
print(requests.get("http://0.0.0.0:8000/hello", params={"firstname": "Łukasz", 'surname':'Kowalski'}).text)
# Out:
# "Hello Łukasz Kowalski!"

# %% [markdown]
# Otwórz stronę http://localhost:8000/docs#/default/say_hello_hello_get i wypróbuj serwis
#
# ![image.png](attachment:1b5ffc35-24bc-4e4e-ae8a-6a3e8c56a6d6.png)

# %% [markdown]
# Otwórz stronę http://localhost:8000/docs#/default/say_hello_hello_get i wypróbuj serwis

# %% [markdown]
# ### 8.2 Wdrożenie zbudowanego zbioru modeli jako mikroserwis

# %% [markdown]
# **TODO 8.2.1** zaimplementuj klasę ```ClassifierDeployment```
# * W konstruktorze przekaż słowniki z modelami i etykietami
# * Zaimplementuj metodę ```calssify`` zgodnie ze specyfikacją

# %%
import requests
from fastapi import FastAPI
from ray import serve
# import uvicorn

# 1: Define a FastAPI app and wrap it in a deployment with a route handler.
app = FastAPI()

@serve.deployment
@serve.ingress(app)
class ClassifierDeployment:
    
    def __init__(self, models, labels):
        self.models = models
        self.labels = labels
        
    # FastAPI will automatically parse the HTTP request for us.
    @app.get("/classify")
    def classify(self, entity: str, text: str) -> str:
        k = ent.lower()
        if not k in self.models:
            k = '*'
            
        y_pred = self.models[k].predict([text])
        return self.labels[k][y_pred[0]]
        
# 2: Deploy the deployment.
app = ClassifierDeployment.bind(models, labels)
serve.run(app, route_prefix="/")
# Out:
# The new client HTTP config differs from the existing one in the following fields: ['host', 'location']. The new HTTP config is ignored.
# 2024-05-23 18:07:30,692	INFO handle.py:126 -- Created DeploymentHandle 'vd57euj1' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:07:31,130	INFO handle.py:126 -- Created DeploymentHandle 'jnlcfduk' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,609	INFO handle.py:126 -- Created DeploymentHandle 'mri0u064' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,656	INFO api.py:584 -- Deployed app 'default' successfully.
# 2024-05-23 18:08:02,678	INFO handle.py:126 -- Created DeploymentHandle 'r4fdyaaf' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,685	INFO handle.py:126 -- Created DeploymentHandle 'g1gnvq4f' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,693	INFO handle.py:126 -- Created DeploymentHandle 'hvdlhjmf' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,705	INFO handle.py:126 -- Created DeploymentHandle 't1rbza8b' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,711	INFO handle.py:126 -- Created DeploymentHandle '3zt0g258' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,714	INFO handle.py:126 -- Created DeploymentHandle 'zf2mnqpl' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,727	INFO handle.py:126 -- Created DeploymentHandle 'zu9tfb4w' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,739	INFO handle.py:126 -- Created DeploymentHandle 'ps5jy5s5' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,746	INFO handle.py:126 -- Created DeploymentHandle 'r7chvdfb' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,761	INFO handle.py:126 -- Created DeploymentHandle 'xiwq7gl1' for Deployment(name='ClassifierDeployment', app='default').
# 2024-05-23 18:08:02,762	INFO handle.py:126 -- Created DeploymentHandle 'nmuebsjy' for Deployment(name='ClassifierDeployment', app='default').
# DeploymentHandle(deployment='ClassifierDeployment')

# %% [markdown]
# Wyświetlimy przykładowe wypowiedzi

# %%
ds_train.filter(lambda row: row['Entity'] == 'Nvidia').random_shuffle(seed=1).to_pandas().head(20)
# Out:
# 2024-05-23 18:08:20,994	INFO streaming_executor.py:108 -- Starting execution of Dataset. Full logs are in /tmp/ray/session_2024-05-23_17-06-58_706767_28/logs/ray-data
# 2024-05-23 18:08:20,997	INFO streaming_executor.py:109 -- Execution plan of Dataset: InputDataBuffer[Input] -> TaskPoolMapOperator[ReadCSV] -> AllToAllOperator[Filter(<lambda>)->RandomShuffle]
# - ReadCSV->SplitBlocks(9) 1:   0%|                                                                            …
# - Filter(<lambda>)->RandomShuffle 2:   0%|                                                                    …
# Shuffle Map 3:   0%|                                                                                          …
# Shuffle Reduce 4:   0%|                                                                                       …
# Running 0:   0%|                                                                                              …
#     TweetId  Entity   Sentiment  \
# 0      9191  Nvidia    Negative
# 1      8865  Nvidia    Positive
# 2      8867  Nvidia    Negative
# 3      8998  Nvidia  Irrelevant
# 4      8891  Nvidia    Positive
# 5      9169  Nvidia    Negative
# 6      9034  Nvidia     Neutral
# 7      8942  Nvidia     Neutral
# 8      9154  Nvidia    Positive
# 9      8905  Nvidia    Positive
# 10     8898  Nvidia     Neutral
# 11     9009  Nvidia     Neutral
# 12     8889  Nvidia    Negative
# 13     9041  Nvidia    Positive
# 14     9058  Nvidia     Neutral
# 15     8953  Nvidia    Negative
# 16     8985  Nvidia     Neutral
# 17     9136  Nvidia    Positive
# 18     8889  Nvidia    Negative
# 19     8978  Nvidia     Neutral
#
#                                          TweetContent
# 0   @ NVIDIAGeForce Damn you Nvidia. You all wante...
# 1   Shiny green new HPC core software dev kit. Int...
# 2   So far nvidia 3080 launch as a fucking shamble...
# 3   This is really interesting for indie role-play...
# 4   Multiple Color GTX 1080ti's are closing at und...
# 5   @BlizzardCSEU_EN ... Can you play wow classic ...
# 6   Nvidia confirmed at global foundries: TSMC is ...
# 7   How to fix the error: NVIDIA Delays the GeForc...
# 8
# 9              5 A single 240hz Monitor sounds juicy.
# 10  Ubuntu freezes according to susopend / hiberna...
# 11  NVIDIA's massive A100 setup here for you dlvr....
# 12  so like, is there even a single game where nvi...
# 13  Exciting times ahead! NVIDIA to Acquire Arm fo...
# 14  HP ENVY x360 15.6. "Screen. 12GB DDR3L, 256ssd...
# 15  year amd launches with enough content to satis...
# 16  @ VixmKalabi This is a more sensible trajector...
# 17  This is actually amazing. It's obviously kinda...
# 18  If so... like, is there even even a damn singl...
# 19  The new Nvidia X 3080 update has just leaked -...

# %% [markdown]
# **TODO 8.2.2** Zamieśc kilka przykładowych wywołań mikroserwisu

# %%
print(requests.get("http://0.0.0.0:8000/classify", params={"entity": "nvidia", 'text': 'so like, is there even a single game where'}).json())
# Out:
# Negative

# %% [markdown]
# ### Bezpośrednie zrzuty ekranu z interfejsu Swaggera

# %% [markdown]
# ![image.png](attachment:d5901881-d211-4647-af9d-4fcbd2139780.png)

# %% [markdown]
# ![image.png](attachment:5e37a6d9-d0c3-4445-bf02-10ce9afa2ac8.png)
